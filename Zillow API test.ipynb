# %%
import pandas as pd
from pandas import json_normalize
import json

# %%
import requests

url = "https://zillow-com1.p.rapidapi.com/propertyExtendedSearch"

querystring = {"location":"raleigh, nc","status_type":"RecentlySold","soldInLast":"24m"}

headers = {
	"X-RapidAPI-Key": "c908b31ea5mshb018fc83e5ca6bcp1fbe04jsn61a6592fc146",
	"X-RapidAPI-Host": "zillow-com1.p.rapidapi.com"
}

response = requests.request("GET", url, headers=headers, params=querystring)

response.json()
# Out:
# {'props': [{'dateSold': 1657868400000,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 6098.4,
#    'address': '8537 Hartham Park Ave, Raleigh, NC 27616',
#    'imgSrc': 'https://photos.zillowstatic.com/fp/839a4c681471ffb7b187d97b69cf68c3-p_e.jpg',
#    'price': 380000,
#    'bedrooms': 2,
#    'longitude': -78.51096,
#    'latitude': 35.897945,
#    'listingStatus': 'RECENTLY_SOLD',
#    'zpid': '111573611',
#    'listingSubType': {},
#    'contingentListingType': None,
#    'daysOnZillow': -1,
#    'bathrooms': 2,
#    'livingArea': 1845,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': 'sqft',
#    'hasImage': True},
#   {'dateSold': 1657868400000,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 5662.8,
#    'address': '4205 Massey Preserve Trl, Raleigh, NC 27616',
#    'imgSrc': 'https://photos.zillowstatic.com/fp/92d14e115c39b1b1126ad2b6b72d9c95-p_e.jpg',
#    'price': 440000,
#    'bedrooms': 4,
#    'longitude': -78.51711,
# ...

# %%
dictr = response.json()
recs = dictr ['props']
df = json_normalize(recs)
df.head()
# Out:
#         dateSold   propertyType  lotAreaValue  \
# 0  1657868400000  SINGLE_FAMILY        6098.4
# 1  1657868400000  SINGLE_FAMILY        5662.8
# 2  1657868400000      TOWNHOUSE         435.6
# 3  1657868400000  SINGLE_FAMILY       10018.8
# 4  1657868400000      TOWNHOUSE        2178.0
#
#                                        address  \
# 0     8537 Hartham Park Ave, Raleigh, NC 27616
# 1  4205 Massey Preserve Trl, Raleigh, NC 27616
# 2  300 Coalinga Ln UNIT 103, Raleigh, NC 27610
# 3             6403 Rosny Rd, Raleigh, NC 27613
# 4   6307 Yates Mill Pond Rd, Raleigh, NC 27606
#
#                                               imgSrc   price  bedrooms  \
# 0  https://photos.zillowstatic.com/fp/839a4c68147...  380000         2
# 1  https://photos.zillowstatic.com/fp/92d14e115c3...  440000         4
# 2  https://photos.zillowstatic.com/fp/44b15fc286e...  292000         3
# 3  https://photos.zillowstatic.com/fp/3a167f878ba...  785000         4
# ...

# %%
#sequence to pull in all flattened data to correct column

# %%
#remove date_sold, imgSrc, listingStatus, listingSubType, contingentListingType, daysOnZillow, country, currency, hasImage

# %%
#check for nulls NaN as appropriate

# %%
#Send clean data to CSV
#clean_wake_df.to_csv('apiTest.csv')

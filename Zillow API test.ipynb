# %%
import pandas as pd
from pandas import json_normalize
import json

# %%
wake_df = []

# %%
# import requests
# import time

# for n in range(1,10):
    
#     url = "https://zillow-com1.p.rapidapi.com/propertyExtendedSearch"

#     querystring = {"location":"wake county, nc","page":n,"status_type":"RecentlySold","soldInLast":"36m"}

#     headers = {
#         "X-RapidAPI-Key": "c908b31ea5mshb018fc83e5ca6bcp1fbe04jsn61a6592fc146",
#         "X-RapidAPI-Host": "zillow-com1.p.rapidapi.com"
#     }

#     response = requests.request("GET", url, headers=headers, params=querystring)
#     time.sleep(1)

# response.json()

# %%
import requests
    
url = "https://zillow-com1.p.rapidapi.com/propertyExtendedSearch"

querystring = {"location":"wake county, nc","page":"1","status_type":"RecentlySold","soldInLast":"36m"}

headers = {
    "X-RapidAPI-Key": "c908b31ea5mshb018fc83e5ca6bcp1fbe04jsn61a6592fc146",
    "X-RapidAPI-Host": "zillow-com1.p.rapidapi.com"
}

response = requests.request("GET", url, headers=headers, params=querystring)


response.json()
dict = response.json()
recs = dict ['props']
wake_df = json_normalize(recs)

# %%
import requests
    
url = "https://zillow-com1.p.rapidapi.com/propertyExtendedSearch"

querystring = {"location":"wake county, nc","page":"2","status_type":"RecentlySold","soldInLast":"36m"}

headers = {
    "X-RapidAPI-Key": "c908b31ea5mshb018fc83e5ca6bcp1fbe04jsn61a6592fc146",
    "X-RapidAPI-Host": "zillow-com1.p.rapidapi.com"
}

response = requests.request("GET", url, headers=headers, params=querystring)


response.json()
dict = response.json()
recs = dict ['props']
df2 = json_normalize(recs)
wake_df = df2.append(wake_df)
# Out:
# C:\Users\19193\AppData\Local\Temp\ipykernel_1784\121997065.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   wake_df = df2.append(wake_df)

# %%
import requests
    
url = "https://zillow-com1.p.rapidapi.com/propertyExtendedSearch"

querystring = {"location":"wake county, nc","page":"3","status_type":"RecentlySold","soldInLast":"36m"}

headers = {
    "X-RapidAPI-Key": "c908b31ea5mshb018fc83e5ca6bcp1fbe04jsn61a6592fc146",
    "X-RapidAPI-Host": "zillow-com1.p.rapidapi.com"
}

response = requests.request("GET", url, headers=headers, params=querystring)


response.json()

dict = response.json()
recs = dict ['props']
df3 = json_normalize(recs)
wake_df = df3.append(wake_df)
# Out:
# C:\Users\19193\AppData\Local\Temp\ipykernel_1784\701571457.py:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   wake_df = df3.append(wake_df)

# %%
import requests
    
url = "https://zillow-com1.p.rapidapi.com/propertyExtendedSearch"

querystring = {"location":"wake county, nc","page":"4","status_type":"RecentlySold","soldInLast":"36m"}

headers = {
    "X-RapidAPI-Key": "c908b31ea5mshb018fc83e5ca6bcp1fbe04jsn61a6592fc146",
    "X-RapidAPI-Host": "zillow-com1.p.rapidapi.com"
}

response = requests.request("GET", url, headers=headers, params=querystring)


response.json()

dict = response.json()
recs = dict ['props']
df4 = json_normalize(recs)
wake_df = df4.append(wake_df)
# Out:
# C:\Users\19193\AppData\Local\Temp\ipykernel_1784\3880164441.py:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   wake_df = df4.append(wake_df)

# %%
import requests
    
url = "https://zillow-com1.p.rapidapi.com/propertyExtendedSearch"

querystring = {"location":"wake county, nc","page":"5","status_type":"RecentlySold","soldInLast":"36m"}

headers = {
    "X-RapidAPI-Key": "c908b31ea5mshb018fc83e5ca6bcp1fbe04jsn61a6592fc146",
    "X-RapidAPI-Host": "zillow-com1.p.rapidapi.com"
}

response = requests.request("GET", url, headers=headers, params=querystring)


response.json()

dict = response.json()
recs = dict ['props']
df5 = json_normalize(recs)
wake_df = df5.append(wake_df)
# Out:
# C:\Users\19193\AppData\Local\Temp\ipykernel_1784\3444623470.py:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   wake_df = df5.append(wake_df)

# %%
import requests
    
url = "https://zillow-com1.p.rapidapi.com/propertyExtendedSearch"

querystring = {"location":"wake county, nc","page":"6","status_type":"RecentlySold","soldInLast":"36m"}

headers = {
    "X-RapidAPI-Key": "c908b31ea5mshb018fc83e5ca6bcp1fbe04jsn61a6592fc146",
    "X-RapidAPI-Host": "zillow-com1.p.rapidapi.com"
}

response = requests.request("GET", url, headers=headers, params=querystring)


response.json()

dict = response.json()
recs = dict ['props']
df6 = json_normalize(recs)
wake_df = df6.append(wake_df)
# Out:
# C:\Users\19193\AppData\Local\Temp\ipykernel_1784\4033037429.py:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   wake_df = df6.append(wake_df)

# %%
import requests
    
url = "https://zillow-com1.p.rapidapi.com/propertyExtendedSearch"

querystring = {"location":"wake county, nc","page":"7","status_type":"RecentlySold","soldInLast":"36m"}

headers = {
    "X-RapidAPI-Key": "c908b31ea5mshb018fc83e5ca6bcp1fbe04jsn61a6592fc146",
    "X-RapidAPI-Host": "zillow-com1.p.rapidapi.com"
}

response = requests.request("GET", url, headers=headers, params=querystring)


response.json()

dict = response.json()
recs = dict ['props']
df7 = json_normalize(recs)
wake_df = df7.append(wake_df)
# Out:
# C:\Users\19193\AppData\Local\Temp\ipykernel_1784\1118190410.py:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   wake_df = df7.append(wake_df)

# %%
import requests
    
url = "https://zillow-com1.p.rapidapi.com/propertyExtendedSearch"

querystring = {"location":"wake county, nc","page":"8","status_type":"RecentlySold","soldInLast":"36m"}

headers = {
    "X-RapidAPI-Key": "c908b31ea5mshb018fc83e5ca6bcp1fbe04jsn61a6592fc146",
    "X-RapidAPI-Host": "zillow-com1.p.rapidapi.com"
}

response = requests.request("GET", url, headers=headers, params=querystring)


response.json()

dict = response.json()
recs = dict ['props']
df8 = json_normalize(recs)
wake_df = df8.append(wake_df)
# Out:
# C:\Users\19193\AppData\Local\Temp\ipykernel_1784\2797958396.py:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   wake_df = df8.append(wake_df)

# %%
import requests
    
url = "https://zillow-com1.p.rapidapi.com/propertyExtendedSearch"

querystring = {"location":"wake county, nc","page":"9","status_type":"RecentlySold","soldInLast":"36m"}

headers = {
    "X-RapidAPI-Key": "c908b31ea5mshb018fc83e5ca6bcp1fbe04jsn61a6592fc146",
    "X-RapidAPI-Host": "zillow-com1.p.rapidapi.com"
}

response = requests.request("GET", url, headers=headers, params=querystring)


response.json()

dict = response.json()
recs = dict ['props']
df9 = json_normalize(recs)
wake_df = df9.append(wake_df)
# Out:
# C:\Users\19193\AppData\Local\Temp\ipykernel_1784\1519808717.py:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   wake_df = df9.append(wake_df)

# %%
import requests
    
url = "https://zillow-com1.p.rapidapi.com/propertyExtendedSearch"

querystring = {"location":"wake county, nc","page":"10","status_type":"RecentlySold","soldInLast":"36m"}

headers = {
    "X-RapidAPI-Key": "c908b31ea5mshb018fc83e5ca6bcp1fbe04jsn61a6592fc146",
    "X-RapidAPI-Host": "zillow-com1.p.rapidapi.com"
}

response = requests.request("GET", url, headers=headers, params=querystring)


response.json()

dict = response.json()
recs = dict ['props']
df = json_normalize(recs)
wake_df = df.append(wake_df)
# Out:
# C:\Users\19193\AppData\Local\Temp\ipykernel_1784\12174933.py:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   wake_df = df.append(wake_df)

# %%
import requests
    
url = "https://zillow-com1.p.rapidapi.com/propertyExtendedSearch"

querystring = {"location":"wake county, nc","page":"11","status_type":"RecentlySold","soldInLast":"36m"}

headers = {
    "X-RapidAPI-Key": "c908b31ea5mshb018fc83e5ca6bcp1fbe04jsn61a6592fc146",
    "X-RapidAPI-Host": "zillow-com1.p.rapidapi.com"
}

response = requests.request("GET", url, headers=headers, params=querystring)


response.json()

dict = response.json()
recs = dict ['props']
df = json_normalize(recs)
wake_df = df.append(wake_df)
# Out:
# C:\Users\19193\AppData\Local\Temp\ipykernel_1784\2574818291.py:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   wake_df = df.append(wake_df)

# %%
import requests
    
url = "https://zillow-com1.p.rapidapi.com/propertyExtendedSearch"

querystring = {"location":"wake county, nc","page":"12","status_type":"RecentlySold","soldInLast":"36m"}

headers = {
    "X-RapidAPI-Key": "c908b31ea5mshb018fc83e5ca6bcp1fbe04jsn61a6592fc146",
    "X-RapidAPI-Host": "zillow-com1.p.rapidapi.com"
}

response = requests.request("GET", url, headers=headers, params=querystring)


response.json()

dict = response.json()
recs = dict ['props']
df = json_normalize(recs)
wake_df = df.append(wake_df)
# Out:
# C:\Users\19193\AppData\Local\Temp\ipykernel_1784\1487601655.py:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   wake_df = df.append(wake_df)

# %%
import requests
    
url = "https://zillow-com1.p.rapidapi.com/propertyExtendedSearch"

querystring = {"location":"wake county, nc","page":"13","status_type":"RecentlySold","soldInLast":"36m"}

headers = {
    "X-RapidAPI-Key": "c908b31ea5mshb018fc83e5ca6bcp1fbe04jsn61a6592fc146",
    "X-RapidAPI-Host": "zillow-com1.p.rapidapi.com"
}

response = requests.request("GET", url, headers=headers, params=querystring)


response.json()

dict = response.json()
recs = dict ['props']
df = json_normalize(recs)
wake_df = df.append(wake_df)
# Out:
# C:\Users\19193\AppData\Local\Temp\ipykernel_1784\3841563619.py:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   wake_df = df.append(wake_df)

# %%
import requests
    
url = "https://zillow-com1.p.rapidapi.com/propertyExtendedSearch"

querystring = {"location":"wake county, nc","page":"14","status_type":"RecentlySold","soldInLast":"36m"}

headers = {
    "X-RapidAPI-Key": "c908b31ea5mshb018fc83e5ca6bcp1fbe04jsn61a6592fc146",
    "X-RapidAPI-Host": "zillow-com1.p.rapidapi.com"
}

response = requests.request("GET", url, headers=headers, params=querystring)


response.json()

dict = response.json()
recs = dict ['props']
df = json_normalize(recs)
wake_df = df.append(wake_df)
# Out:
# C:\Users\19193\AppData\Local\Temp\ipykernel_1784\10588045.py:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   wake_df = df.append(wake_df)

# %%
import requests
    
url = "https://zillow-com1.p.rapidapi.com/propertyExtendedSearch"

querystring = {"location":"wake county, nc","page":"15","status_type":"RecentlySold","soldInLast":"36m"}

headers = {
    "X-RapidAPI-Key": "c908b31ea5mshb018fc83e5ca6bcp1fbe04jsn61a6592fc146",
    "X-RapidAPI-Host": "zillow-com1.p.rapidapi.com"
}

response = requests.request("GET", url, headers=headers, params=querystring)


response.json()

dict = response.json()
recs = dict ['props']
df = json_normalize(recs)
wake_df = df.append(wake_df)
# Out:
# C:\Users\19193\AppData\Local\Temp\ipykernel_1784\1694854130.py:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   wake_df = df.append(wake_df)

# %%
import requests
    
url = "https://zillow-com1.p.rapidapi.com/propertyExtendedSearch"

querystring = {"location":"wake county, nc","page":"16","status_type":"RecentlySold","soldInLast":"36m"}

headers = {
    "X-RapidAPI-Key": "c908b31ea5mshb018fc83e5ca6bcp1fbe04jsn61a6592fc146",
    "X-RapidAPI-Host": "zillow-com1.p.rapidapi.com"
}

response = requests.request("GET", url, headers=headers, params=querystring)


response.json()

dict = response.json()
recs = dict ['props']
df = json_normalize(recs)
wake_df = df.append(wake_df)
# Out:
# C:\Users\19193\AppData\Local\Temp\ipykernel_1784\1091853790.py:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   wake_df = df.append(wake_df)

# %%
import requests
    
url = "https://zillow-com1.p.rapidapi.com/propertyExtendedSearch"

querystring = {"location":"wake county, nc","page":"17","status_type":"RecentlySold","soldInLast":"36m"}

headers = {
    "X-RapidAPI-Key": "c908b31ea5mshb018fc83e5ca6bcp1fbe04jsn61a6592fc146",
    "X-RapidAPI-Host": "zillow-com1.p.rapidapi.com"
}

response = requests.request("GET", url, headers=headers, params=querystring)


response.json()

dict = response.json()
recs = dict ['props']
df = json_normalize(recs)
wake_df = df.append(wake_df)
# Out:
# C:\Users\19193\AppData\Local\Temp\ipykernel_1784\1580042187.py:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   wake_df = df.append(wake_df)

# %%
import requests
    
url = "https://zillow-com1.p.rapidapi.com/propertyExtendedSearch"

querystring = {"location":"wake county, nc","page":"18","status_type":"RecentlySold","soldInLast":"36m"}

headers = {
    "X-RapidAPI-Key": "c908b31ea5mshb018fc83e5ca6bcp1fbe04jsn61a6592fc146",
    "X-RapidAPI-Host": "zillow-com1.p.rapidapi.com"
}

response = requests.request("GET", url, headers=headers, params=querystring)


response.json()

dict = response.json()
recs = dict ['props']
df = json_normalize(recs)
wake_df = df.append(wake_df)
# Out:
# C:\Users\19193\AppData\Local\Temp\ipykernel_1784\1535803037.py:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   wake_df = df.append(wake_df)

# %%
import requests
    
url = "https://zillow-com1.p.rapidapi.com/propertyExtendedSearch"

querystring = {"location":"wake county, nc","page":"19","status_type":"RecentlySold","soldInLast":"36m"}

headers = {
    "X-RapidAPI-Key": "c908b31ea5mshb018fc83e5ca6bcp1fbe04jsn61a6592fc146",
    "X-RapidAPI-Host": "zillow-com1.p.rapidapi.com"
}

response = requests.request("GET", url, headers=headers, params=querystring)


response.json()

dict = response.json()
recs = dict ['props']
df = json_normalize(recs)
wake_df = df.append(wake_df)
# Out:
# C:\Users\19193\AppData\Local\Temp\ipykernel_1784\4105105165.py:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   wake_df = df.append(wake_df)

# %%
import requests
    
url = "https://zillow-com1.p.rapidapi.com/propertyExtendedSearch"

querystring = {"location":"wake county, nc","page":"20","status_type":"RecentlySold","soldInLast":"36m"}

headers = {
    "X-RapidAPI-Key": "c908b31ea5mshb018fc83e5ca6bcp1fbe04jsn61a6592fc146",
    "X-RapidAPI-Host": "zillow-com1.p.rapidapi.com"
}

response = requests.request("GET", url, headers=headers, params=querystring)


response.json()

dict = response.json()
recs = dict ['props']
df = json_normalize(recs)
wake_df = df.append(wake_df)
# Out:
# C:\Users\19193\AppData\Local\Temp\ipykernel_1784\1035300350.py:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   wake_df = df.append(wake_df)

# %%
wake_df

# %%
import requests
    
url = "https://zillow-com1.p.rapidapi.com/propertyExtendedSearch"

querystring = {"location":"wake county, nc","page":"21","status_type":"RecentlySold","soldInLast":"36m"}

headers = {
    "X-RapidAPI-Key": "c908b31ea5mshb018fc83e5ca6bcp1fbe04jsn61a6592fc146",
    "X-RapidAPI-Host": "zillow-com1.p.rapidapi.com"
}

response = requests.request("GET", url, headers=headers, params=querystring)


response.json()

dict = response.json()
recs = dict ['props']
df = json_normalize(recs)
wake_df = df.append(wake_df)
# Out:
# C:\Users\19193\AppData\Local\Temp\ipykernel_1784\1136611388.py:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   wake_df = df.append(wake_df)

# %%
import requests
    
url = "https://zillow-com1.p.rapidapi.com/propertyExtendedSearch"

querystring = {"location":"wake county, nc","page":"22","status_type":"RecentlySold","soldInLast":"36m"}

headers = {
    "X-RapidAPI-Key": "c908b31ea5mshb018fc83e5ca6bcp1fbe04jsn61a6592fc146",
    "X-RapidAPI-Host": "zillow-com1.p.rapidapi.com"
}

response = requests.request("GET", url, headers=headers, params=querystring)


response.json()

dict = response.json()
recs = dict ['props']
df = json_normalize(recs)
wake_df = df.append(wake_df)
# Out:
# C:\Users\19193\AppData\Local\Temp\ipykernel_1784\2617016446.py:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   wake_df = df.append(wake_df)

# %%
import requests
    
url = "https://zillow-com1.p.rapidapi.com/propertyExtendedSearch"

querystring = {"location":"wake county, nc","page":"23","status_type":"RecentlySold","soldInLast":"36m"}

headers = {
    "X-RapidAPI-Key": "c908b31ea5mshb018fc83e5ca6bcp1fbe04jsn61a6592fc146",
    "X-RapidAPI-Host": "zillow-com1.p.rapidapi.com"
}

response = requests.request("GET", url, headers=headers, params=querystring)


response.json()

dict = response.json()
recs = dict ['props']
df = json_normalize(recs)
wake_df = df.append(wake_df)
# Out:
# C:\Users\19193\AppData\Local\Temp\ipykernel_1784\627956754.py:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   wake_df = df.append(wake_df)

# %%
import requests
    
url = "https://zillow-com1.p.rapidapi.com/propertyExtendedSearch"

querystring = {"location":"wake county, nc","page":"24","status_type":"RecentlySold","soldInLast":"36m"}

headers = {
    "X-RapidAPI-Key": "c908b31ea5mshb018fc83e5ca6bcp1fbe04jsn61a6592fc146",
    "X-RapidAPI-Host": "zillow-com1.p.rapidapi.com"
}

response = requests.request("GET", url, headers=headers, params=querystring)


response.json()

dict = response.json()
recs = dict ['props']
df = json_normalize(recs)
wake_df = df.append(wake_df)
# Out:
# C:\Users\19193\AppData\Local\Temp\ipykernel_1784\2213955207.py:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   wake_df = df.append(wake_df)

# %%
import requests
    
url = "https://zillow-com1.p.rapidapi.com/propertyExtendedSearch"

querystring = {"location":"wake county, nc","page":"25","status_type":"RecentlySold","soldInLast":"36m"}

headers = {
    "X-RapidAPI-Key": "c908b31ea5mshb018fc83e5ca6bcp1fbe04jsn61a6592fc146",
    "X-RapidAPI-Host": "zillow-com1.p.rapidapi.com"
}

response = requests.request("GET", url, headers=headers, params=querystring)


response.json()

dict = response.json()
recs = dict ['props']
df = json_normalize(recs)
wake_df = df.append(wake_df)
# Out:
# C:\Users\19193\AppData\Local\Temp\ipykernel_1784\4157234819.py:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   wake_df = df.append(wake_df)

# %%
wake_df
# Out:
#          dateSold   propertyType  lotAreaValue  \
# 0   1657177200000  SINGLE_FAMILY      0.510000
# 1   1657177200000  SINGLE_FAMILY      0.620000
# 2   1657177200000  SINGLE_FAMILY   8276.400000
# 3   1657177200000  SINGLE_FAMILY      0.359986
# 4   1657177200000  SINGLE_FAMILY      0.290000
# ..            ...            ...           ...
# 35  1658473200000  SINGLE_FAMILY      0.340000
# 36  1658473200000  SINGLE_FAMILY   1742.400000
# 37  1658473200000  SINGLE_FAMILY      0.550000
# 38  1658473200000  SINGLE_FAMILY   7405.200000
# 39  1658473200000  SINGLE_FAMILY      0.360000
#
#                                        address  \
# 0        5700 Meadowlark Ln, Raleigh, NC 27610
# 1         4205 Stonewall Dr, Raleigh, NC 27604
# 2           400 Pershing Rd, Raleigh, NC 27608
# 3              214 Fairview Rd, Cary, NC 27511
# 4         3101 Merrianne Dr, Raleigh, NC 27607
# ..                                         ...
# 35             2115 Peabody Pl, Apex, NC 27523
# ...

# %%
safe_wake_df = wake_df

# %%
wake_df.dtypes
# Out:
# dateSold                    int64
# propertyType               object
# lotAreaValue              float64
# address                    object
# imgSrc                     object
# price                       int64
# bedrooms                  float64
# longitude                 float64
# latitude                  float64
# listingStatus              object
# zpid                       object
# contingentListingType      object
# daysOnZillow                int64
# bathrooms                 float64
# livingArea                float64
# country                    object
# currency                   object
# lotAreaUnit                object
# hasImage                   object
# unit                       object
# listingSubType.is_FSBA     object
# listingSubType.is_FSBO     object
# dtype: object

# %%
#sequence to pull in all flattened data to correct column
wake_df = wake_df.drop(['dateSold', 'imgSrc', 'unit', 'contingentListingType', 'daysOnZillow', 'country', 'currency', 'hasImage', 'listingSubType.is_FSBA','listingSubType.is_FSBO'], axis=1)
wake_df
# Out:
#      propertyType  lotAreaValue                                     address  \
# 0   SINGLE_FAMILY      0.510000       5700 Meadowlark Ln, Raleigh, NC 27610
# 1   SINGLE_FAMILY      0.620000        4205 Stonewall Dr, Raleigh, NC 27604
# 2   SINGLE_FAMILY   8276.400000          400 Pershing Rd, Raleigh, NC 27608
# 3   SINGLE_FAMILY      0.359986             214 Fairview Rd, Cary, NC 27511
# 4   SINGLE_FAMILY      0.290000        3101 Merrianne Dr, Raleigh, NC 27607
# ..            ...           ...                                         ...
# 35  SINGLE_FAMILY      0.340000             2115 Peabody Pl, Apex, NC 27523
# 36  SINGLE_FAMILY   1742.400000      10522 Shadowlawn Dr, Raleigh, NC 27614
# 37  SINGLE_FAMILY      0.550000  2608 Loring Lake Dr, Wake Forest, NC 27587
# 38  SINGLE_FAMILY   7405.200000      9229 Shallcross Way, Raleigh, NC 27617
# 39  SINGLE_FAMILY      0.360000     10600 Charlesgate Ct, Raleigh, NC 27614
#
# ...

# %%
test_df = wake_df
test_df
# Out:
#      propertyType  lotAreaValue                                     address  \
# 0   SINGLE_FAMILY      0.510000       5700 Meadowlark Ln, Raleigh, NC 27610
# 1   SINGLE_FAMILY      0.620000        4205 Stonewall Dr, Raleigh, NC 27604
# 2   SINGLE_FAMILY   8276.400000          400 Pershing Rd, Raleigh, NC 27608
# 3   SINGLE_FAMILY      0.359986             214 Fairview Rd, Cary, NC 27511
# 4   SINGLE_FAMILY      0.290000        3101 Merrianne Dr, Raleigh, NC 27607
# ..            ...           ...                                         ...
# 35  SINGLE_FAMILY      0.340000             2115 Peabody Pl, Apex, NC 27523
# 36  SINGLE_FAMILY   1742.400000      10522 Shadowlawn Dr, Raleigh, NC 27614
# 37  SINGLE_FAMILY      0.550000  2608 Loring Lake Dr, Wake Forest, NC 27587
# 38  SINGLE_FAMILY   7405.200000      9229 Shallcross Way, Raleigh, NC 27617
# 39  SINGLE_FAMILY      0.360000     10600 Charlesgate Ct, Raleigh, NC 27614
#
# ...

# %%
lav = wake_df.loc[test_df['lotAreaUnit'] == 'sqft', 'lotAreaValue']

# %%
lav = lav/43560

# %%
print(lav)
# Out:
# 2     0.19
# 11    0.17
# 14    0.15
# 16    0.03
# 17    0.03
#       ...
# 29    0.17
# 30    0.20
# 34    0.15
# 36    0.04
# 38    0.17
# Name: lotAreaValue, Length: 543, dtype: float64

# %%
test_df.loc[test_df['lotAreaUnit'] == 'sqft', 'lotAreaValue'] = lav
test_df
# Out:
#      propertyType  lotAreaValue                                     address  \
# 0   SINGLE_FAMILY      0.510000       5700 Meadowlark Ln, Raleigh, NC 27610
# 1   SINGLE_FAMILY      0.620000        4205 Stonewall Dr, Raleigh, NC 27604
# 2   SINGLE_FAMILY      0.190000          400 Pershing Rd, Raleigh, NC 27608
# 3   SINGLE_FAMILY      0.359986             214 Fairview Rd, Cary, NC 27511
# 4   SINGLE_FAMILY      0.290000        3101 Merrianne Dr, Raleigh, NC 27607
# ..            ...           ...                                         ...
# 35  SINGLE_FAMILY      0.340000             2115 Peabody Pl, Apex, NC 27523
# 36  SINGLE_FAMILY      0.040000      10522 Shadowlawn Dr, Raleigh, NC 27614
# 37  SINGLE_FAMILY      0.550000  2608 Loring Lake Dr, Wake Forest, NC 27587
# 38  SINGLE_FAMILY      0.170000      9229 Shallcross Way, Raleigh, NC 27617
# 39  SINGLE_FAMILY      0.360000     10600 Charlesgate Ct, Raleigh, NC 27614
#
# ...

# %%
wake_df = test_df

# %%
wake_df['address'] = wake_df.address.str[-5:]

# %%
wake_df = wake_df.drop(['lotAreaUnit', 'listingStatus'], axis=1)

# %%
wake_df
# Out:
#      propertyType  lotAreaValue address    price  bedrooms  longitude  \
# 0   SINGLE_FAMILY      0.510000   27610   251000       3.0 -78.542496
# 1   SINGLE_FAMILY      0.620000   27604   265000       3.0 -78.566910
# 2   SINGLE_FAMILY      0.190000   27608  1352000       4.0 -78.634760
# 3   SINGLE_FAMILY      0.359986   27511   510000       3.0 -78.777230
# 4   SINGLE_FAMILY      0.290000   27607   560000       3.0 -78.687560
# ..            ...           ...     ...      ...       ...        ...
# 35  SINGLE_FAMILY      0.340000   27523   635000       4.0 -78.883300
# 36  SINGLE_FAMILY      0.040000   27614   360000       3.0 -78.590454
# 37  SINGLE_FAMILY      0.550000   27587   482500       3.0 -78.540474
# 38  SINGLE_FAMILY      0.170000   27617   549900       4.0 -78.732414
# 39  SINGLE_FAMILY      0.360000   27614   750000       4.0 -78.583900
#
#      latitude      zpid  bathrooms  livingArea
# 0   35.758920   6402949        2.0      1515.0
# ...

# %%
#Send clean data to CSV
wake_df.to_csv('Resources/zillow.csv')

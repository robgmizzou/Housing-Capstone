# %%
import pandas as pd

# %%
df = pd.read_csv('sbux.csv')

# %%
df.head()
# Out:
#        Brand  Store Number                 Store Name Ownership Type  \
# 0  Starbucks  10387-100533               Aberdeen, NC  Company Owned
# 1  Starbucks   72999-98079     Harris Teeter-Apex #58       Licensed
# 2  Starbucks  72522-104988           Kroger-Apex #357       Licensed
# 3  Starbucks   76255-94937  Super Target Apex ST-1932       Licensed
# 4  Starbucks   76409-95670    Target Asheville T-2011       Licensed
#
#                  Street Address      City State/Province Country   Postcode  \
# 0            110 Columbus Drive  Aberdeen             NC      US  283152387
# 1             750 W Williams St      Apex             NC      US  275025100
# 2                 940 US Hwy 64      Apex             NC      US  275237184
# 3  1201 Beaver Creek Commons Dr      Apex             NC      US  275023922
# 4                 15 McKenna Rd     Arden             NC      US  287049201
#
#    Phone Number                    Timezone  Longitude  Latitude
# ...

# %%
df = df.drop(['Brand','Store Number', 'Ownership Type', 'State/Province','Country','Phone Number', 'Timezone'],axis=1)

# %%
df.dtypes
# Out:
# Store Name         object
# Street Address     object
# City               object
# Postcode           object
# Longitude         float64
# Latitude          float64
# dtype: object

# %%
df['Postcode'] = df.Postcode.str[0:5]
df
# Out:
#                               Store Name                      Street Address  \
# 0                           Aberdeen, NC                  110 Columbus Drive
# 1                 Harris Teeter-Apex #58                   750 W Williams St
# 2                       Kroger-Apex #357                       940 US Hwy 64
# 3              Super Target Apex ST-1932        1201 Beaver Creek Commons Dr
# 4                Target Asheville T-2011                       15 McKenna Rd
# ..                                   ...                                 ...
# 333                     Hanes Mall Blvd.        2015 Frontis Plaza Boulevard
# 334                       Stratford Road  110 Oakwood Drive, Space U122, N/A
# 335                        Reynolda Road                  2898 Reynolda Road
# 336  Wake Forest University Z. Smith Rey                 1834 Wake Forest Rd
# 337  Wake Forest Unv Bap Med - Winst-Sal               1 Medical Center Blvd
#
# ...

# %%
#Send clean data to CSV
df.to_csv('Resources/final_sbux.csv')
